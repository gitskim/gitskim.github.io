# %%
import numpy as np
import scipy.ndimage as nd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
def make_test_image(N=512):
    X = np.random.randint(0, 64, (N, N))

    for k in range(6):
        i0, j0 = np.random.randint(0, N-32, 2)
        i1 = np.random.randint(i0 + 8, N)
        j1 = np.random.randint(j0 + 8, N)
        X[i0 : i1, j0 : j1] = np.cumsum(
            np.random.randint(0, 6, (i1 - i0, j1 - j0)),
            axis=k%2
        )
    X = np.minimum(X, 255)
    return X

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(make_test_image())
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
image = np.random.randint(0, 5, (16, 16))

# %%
image = make_test_image()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(image)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
stencil = np.array([[-1, 0], [0, 1]])

# %%
stencil
# Out:
# array([[-1,  0],
#        [ 0,  1]])

# %%
conv = np.array([
    [np.sum(image[i:i+2, j:j+2] * stencil) for j in range(510)]
    for i in range(510)])

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.imshow(conv)
# Out:
# <img src="data:image/png;base64,..." width="640">
